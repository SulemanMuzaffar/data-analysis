# %%
import pandas as pd
df = pd.read_csv('sales-data-sample.csv') #read csv file
df.head(5)
# Out:
#                   OrderDate         Category          City        Country  \
# 0  2011-01-04T00:00:00.000Z  Office Supplies       Houston  United States
# 1  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 2  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 3  2011-01-05T00:00:00.000Z  Office Supplies    Naperville  United States
# 4  2011-01-06T00:00:00.000Z  Office Supplies  Philadelphia  United States
#
#     CustomerName  Discount         OrderID  PostalCode  \
# 0  Darren Powers       0.2  CA-2011-103800       77095
# 1  Phillina Ober       0.2  CA-2011-112326       60540
# 2  Phillina Ober       0.8  CA-2011-112326       60540
# 3  Phillina Ober       0.2  CA-2011-112326       60540
# 4     Mick Brown       0.2  CA-2011-141817       19143
#
#                                          ProductName  Profit  ...  \
# 0  Message Book, Wirebound, Four 5 1/2 X 4 Forms/...       6  ...
# ...

# %%
columns = list(df.columns) #put columns into a new dataframe
columns
# Out:
# ['OrderDate',
#  'Category',
#  'City',
#  'Country',
#  'CustomerName',
#  'Discount',
#  'OrderID',
#  'PostalCode',
#  'ProductName',
#  'Profit',
#  'Quantity',
#  'Region',
#  'Sales',
#  'Segment',
#  'ShipDate',
#  'ShipMode',
#  'State',
#  'Sub_Category',
#  'DaystoShipActual',
#  'SalesForecast',
#  'ShipStatus',
#  'DaystoShipScheduled',
#  'OrderProfitable',
#  'SalesperCustomer',
#  'ProfitRatio',
#  'SalesaboveTarget',
#  'latitude',
#  'longitude']

# %%
df_datetime = pd.to_datetime(df["OrderDate"]) ##Cast to Date time format
df_datetime_o = pd.to_datetime(df["ShipDate"]) ##Case to date time format

# %%
df_date = df_datetime.dt.date  ##Removing Time from Datetime dataframe
df_date.head()
df_date_o = df_datetime.dt.date
df_date_o.head()
# Out:
# 0    2011-01-04
# 1    2011-01-05
# 2    2011-01-05
# 3    2011-01-05
# 4    2011-01-06
# Name: OrderDate, dtype: object

# %%
df['Order Date'] = df_date ##Appending the column to df_new
df['Shipping Date'] = df_date_o

# %%
df = df.drop(['OrderDate', 'ShipDate', 'OrderProfitable', 'SalesaboveTarget'],axis="columns") ##Drop Extra Columns

# %%
df = df.infer_objects() ##infer objects to specific datatypes
df.head()
# Out:
#           Category          City        Country   CustomerName  Discount  \
# 0  Office Supplies       Houston  United States  Darren Powers       0.2
# 1  Office Supplies    Naperville  United States  Phillina Ober       0.2
# 2  Office Supplies    Naperville  United States  Phillina Ober       0.8
# 3  Office Supplies    Naperville  United States  Phillina Ober       0.2
# 4  Office Supplies  Philadelphia  United States     Mick Brown       0.2
#
#           OrderID  PostalCode  \
# 0  CA-2011-103800       77095
# 1  CA-2011-112326       60540
# 2  CA-2011-112326       60540
# 3  CA-2011-112326       60540
# 4  CA-2011-141817       19143
#
#                                          ProductName  Profit  Quantity  ...  \
# 0  Message Book, Wirebound, Four 5 1/2 X 4 Forms/...       6         2  ...
# 1                                          Avery 508       4         3  ...
# 2         GBC Standard Plastic Binding Systems Combs      -5         2  ...
# ...

# %%
df.info() ##check for the datatypes of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             9994 non-null   object
#  1   City                 9994 non-null   object
#  2   Country              9994 non-null   object
#  3   CustomerName         9994 non-null   object
#  4   Discount             9994 non-null   float64
#  5   OrderID              9994 non-null   object
#  6   PostalCode           9994 non-null   int64
#  7   ProductName          9994 non-null   object
#  8   Profit               9994 non-null   int64
#  9   Quantity             9994 non-null   int64
#  10  Region               9994 non-null   object
#  11  Sales                9994 non-null   int64
#  12  Segment              9994 non-null   object
#  13  ShipMode             9994 non-null   object
#  14  State                9994 non-null   object
# ...

# %%
df.to_csv('CleanedSalesData.csv',index='false') ##Export the cleaned data to csv
